# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
monedas_estables = pd.read_csv('rangomenor.csv')

# Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
monedas_estables.plot(x="moneda", y="Rango", kind="bar", legend=False)

plt.title("Monedas más estables")
plt.xlabel("Monedas")
plt.ylabel("Rango")
plt.grid()


plt.show()

# %%
monedas_caras = pd.read_csv('mayorvalor.csv')


#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
monedas_caras.plot(x="moneda", y="promedio", kind="bar", legend=False)

plt.title("Monedas de mayor costo")
plt.xlabel("monedas")
plt.ylabel("promedio")
plt.grid()

plt.show()

# %%
monedas_caras = pd.read_csv('mayorvalor.csv')


#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
monedas_caras.plot(x="moneda", y="promedio", kind="bar", legend=False)

plt.title("Monedas de mayor costo")
plt.xlabel("monedas")
plt.ylabel("promedio")
plt.grid()

plt.show()

# %%
monedas_caras = pd.read_csv('mayorvalor.csv')


#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
monedas_caras.plot(x="moneda", y="promedio", kind="bar", legend=False)

plt.title("Monedas de mayor costo")
plt.xlabel("monedas")
plt.ylabel("promedio")
plt.grid()

plt.show()

# %%
monedas_estables.head(10)
# Out:
#         moneda     Rango
# 0     ShibaInu  0.000002
# 1        eCash  0.000022
# 2         Holo  0.002287
# 3      VeChain  0.004154
# 4         tron  0.004251
# 5      Zilliqa  0.005898
# 6     dogecoin  0.006816
# 7         USDD  0.007214
# 8  Binance_USD  0.007703
# 9      TrueUSD  0.011053

# %%
monedas_baratas = pd.read_csv('menorvalor.csv')
monedas_baratas.head()


#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
monedas_baratas.plot(x="moneda", y="promedio", kind="bar", legend=False)

plt.title("Monedas con menor costo")
plt.xlabel("monedas")
plt.ylabel("promedio")
plt.grid()

plt.show()

# %%
mas_transitadas = pd.read_csv('mas_Transacciones.csv')


#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
mas_transitadas.plot(x="moneda", y="Volume", kind="bar", legend=False)

plt.title("Monedas con mas transacciones")
plt.xlabel("monedas")
plt.ylabel("Transacciones")
plt.grid()

plt.show()

# %%
valor_mayor_pro = pd.read_csv('valormayorpro.csv')
valor_mayor_pro.head(10)

#Configurar el gráfico
plt.figure(figsize=(10, 6))  # Ajustar el tamaño del gráfico
valor_mayor_pro.plot(x="moneda", y="promedio", kind="bar", legend=False)
plt.title("Monedas con mayor valor al promedio")
plt.xlabel("monedas")
plt.ylabel("promedio")
plt.grid()

plt.show()

# %%
tron = pd.read_csv('tron.csv')
tron.head()
precio_tron = tron[['date', 'price']]
precio_tron.head()

# Graficar
precio_tron.plot(x="date", y="price", kind="line", marker='o')
plt.title("Moneda Tron")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas del eje X
plt.grid()

# Mostrar el gráfico
plt.show()

# %%
tron = pd.read_csv('vechain.csv')
tron.head()
precio_tron = tron[['date', 'price']]
precio_tron.head()

# Graficar
precio_tron.plot(x="date", y="price", kind="line", marker='o')
plt.title("Moneda vechain")
plt.xlabel("Tiempo")
plt.ylabel("Precio")
plt.xticks(rotation=45)  # Rotar etiquetas del eje X
plt.grid()

# Mostrar el gráfico
plt.show()
